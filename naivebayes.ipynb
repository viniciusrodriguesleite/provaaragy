# %% [markdown]
# FUNDAMENTAÇÃO BASICA: O algoritmo naive bayes supõe que há uma independência entre as features do modelo. Isso significa que a presença de uma determinada feature não tem nenhuma relação com as outras. No caso de um texto, o classificador assume que as palavras não tem uma relação entre elas.
#
# TIPO DE CLASSIFICAÇÃO: probabilistico.

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib.colors as colors
import seaborn as sns
import itertools
from scipy.stats import norm
import scipy.stats
from sklearn.naive_bayes import GaussianNB

# %matplotlib inline
sns.set()

# %%
#carregar o conjunto de dados
iris = sns.load_dataset("iris")
iris = iris.rename(index = str, columns = {'sepal_length':'1_sepal_length','sepal_width':'2_sepal_width', 'petal_length':'3_petal_length', 'petal_width':'4_petal_width'})

#traçar a dispersão de comprimento e largura da sépala
sns.FacetGrid(iris, hue="species", size=7) .map(plt.scatter,"1_sepal_length", "2_sepal_width", )  .add_legend()
plt.title('Scatter plot')
df1 = iris[["1_sepal_length", "2_sepal_width",'species']]
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
